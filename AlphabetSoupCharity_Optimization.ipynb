# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head(5)
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(['EIN','NAME'], axis=1)
application_df.head(5)
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=['T9','T13','T12','T2','T14','T25','T15','T29','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classifications_to_replace.loc[classifications_to_replace<1200].index.values


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_dummies = pd.get_dummies(application_df, drop_first=True)
df_dummies.head(5)
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  ORGANIZATION_Trust  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
X=df_dummies.drop("IS_SUCCESSFUL",axis=1)
y=df_dummies["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Model 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=40, activation="relu", input_dim=36))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=20, activation="relu"))

#Third Hidden Layer
nn_model.add(tf.keras.layers.Dense(units=10, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 40)                1480
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                820
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# ...
# Total params: 2,521
# Trainable params: 2,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 831us/step - loss: 0.5804 - accuracy: 0.7076
# Epoch 2/100
# 804/804 [==============================] - 1s 850us/step - loss: 0.5558 - accuracy: 0.7301
# Epoch 3/100
# 804/804 [==============================] - 1s 777us/step - loss: 0.5534 - accuracy: 0.7309
# Epoch 4/100
# 804/804 [==============================] - 1s 853us/step - loss: 0.5517 - accuracy: 0.7313
# Epoch 5/100
# 804/804 [==============================] - 1s 818us/step - loss: 0.5504 - accuracy: 0.7337
# Epoch 6/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5494 - accuracy: 0.7338
# Epoch 7/100
# 804/804 [==============================] - 1s 841us/step - loss: 0.5488 - accuracy: 0.7341
# Epoch 8/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5488 - accuracy: 0.7330
# Epoch 9/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5482 - accuracy: 0.7332
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5542 - accuracy: 0.7235
# Loss: 0.5542394518852234, Accuracy: 0.723498523235321

# %% [markdown]
# # Results of Model 1
# Added a nother hidden layer (maintained relu with all three layers) and adjusted the epochs to 100. Resulted in slightly better than the test data with a lower loss but the accuracy is almost identical

# %% [markdown]
# # Model 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create the Keras Sequential model
nn_model_2 = tf.keras.models.Sequential()

# First hidden layer
nn_model_2.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=36))

# Output layer
nn_model_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 20)                740
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 21
# ...
# Total params: 761
# Trainable params: 761
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model_2.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 743us/step - loss: 0.6025 - accuracy: 0.7019
# Epoch 2/200
# 804/804 [==============================] - 1s 813us/step - loss: 0.5658 - accuracy: 0.7259
# Epoch 3/200
# 804/804 [==============================] - 1s 774us/step - loss: 0.5605 - accuracy: 0.7276
# Epoch 4/200
# 804/804 [==============================] - 1s 798us/step - loss: 0.5582 - accuracy: 0.7296
# Epoch 5/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5561 - accuracy: 0.7291
# Epoch 6/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5548 - accuracy: 0.7299
# Epoch 7/200
# 804/804 [==============================] - 1s 765us/step - loss: 0.5539 - accuracy: 0.7310
# Epoch 8/200
# 804/804 [==============================] - 1s 724us/step - loss: 0.5533 - accuracy: 0.7301
# Epoch 9/200
# 804/804 [==============================] - 1s 700us/step - loss: 0.5524 - accuracy: 0.7303
# Epoch 10/200
# ...

# %%
model_loss, model_accuracy = nn_model_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5525 - accuracy: 0.7270
# Loss: 0.5525379180908203, Accuracy: 0.7269970774650574

# %% [markdown]
# # Results of Model 2
# I adjusted to only one hidden layer but upped the epochs to 200. This did result in better scores with both loss and accuracy.

# %% [markdown]
# # Model 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create the Keras Sequential model
nn_model_3 = tf.keras.models.Sequential()

# First hidden layer
nn_model_3.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim=36))

#Third Hidden Layer
nn_model_3.add(tf.keras.layers.Dense(units=10, activation="relu"))

# Output layer
nn_model_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model_3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 20)                740
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# ...
# Total params: 961
# Trainable params: 961
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model_3.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 787us/step - loss: 0.5992 - accuracy: 0.7009
# Epoch 2/200
# 804/804 [==============================] - 1s 812us/step - loss: 0.5623 - accuracy: 0.7288
# Epoch 3/200
# 804/804 [==============================] - 1s 742us/step - loss: 0.5585 - accuracy: 0.7297
# Epoch 4/200
# 804/804 [==============================] - 1s 752us/step - loss: 0.5554 - accuracy: 0.7322
# Epoch 5/200
# 804/804 [==============================] - 1s 745us/step - loss: 0.5543 - accuracy: 0.7325
# Epoch 6/200
# 804/804 [==============================] - 1s 735us/step - loss: 0.5535 - accuracy: 0.7329
# Epoch 7/200
# 804/804 [==============================] - 1s 756us/step - loss: 0.5524 - accuracy: 0.7342
# Epoch 8/200
# 804/804 [==============================] - 1s 735us/step - loss: 0.5524 - accuracy: 0.7325
# Epoch 9/200
# 804/804 [==============================] - 1s 746us/step - loss: 0.5514 - accuracy: 0.7316
# Epoch 10/200
# ...

# %%
model_loss, model_accuracy = nn_model_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5550 - accuracy: 0.7234
# Loss: 0.5550183653831482, Accuracy: 0.7233819365501404

# %% [markdown]
# # Model 3 Results
